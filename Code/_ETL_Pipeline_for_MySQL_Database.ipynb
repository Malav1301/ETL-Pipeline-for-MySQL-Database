# %%
import pandas as pd

# %%
customers = pd.read_csv(r"C:\Users\patel\Downloads\Data for ETL Assignment - Customers.csv")
orders = pd.read_csv(r"C:\Users\patel\Downloads\Data for ETL Assignment - Orders.csv")
products = pd.read_csv(r"C:\Users\patel\Downloads\Data for ETL Assignment - Products.csv")
payments = pd.read_csv(r"C:\Users\patel\Downloads\Data for ETL Assignment - Payments.csv")

# %% [markdown]
#  # Reading and cleaning Customers table

# %%
customers.head()
# Out:
#    customer_id first_name last_name                      email  \
# 0            1     Regina     Banks           kjones@petty.biz
# 1            2       Mark      Pena      mercedes42@warner.com
# 2            3     Amanda    Carney   ricardosimmons@gmail.com
# 3            4    Brandon       Lee  kelleycharles@hotmail.com
# 4            5    Theresa   Ramirez        amybrown@butler.biz
#
#             phone_number           created_at
# 0       374.831.2327x000  2022-11-20 19:15:32
# 1  001-698-370-1197x3825  2025-02-08 03:18:03
# 2           946-520-9112  2022-06-28 09:04:15
# 3     915.139.9155x10333  2023-03-06 14:40:08
# 4    (307)514-8871x86410  2024-08-19 05:20:11

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   customer_id   100 non-null    int64
#  1   first_name    100 non-null    object
#  2   last_name     100 non-null    object
#  3   email         100 non-null    object
#  4   phone_number  100 non-null    object
#  5   created_at    100 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 4.8+ KB

# %%
customers.isnull().sum()
# Out:
# customer_id     0
# first_name      0
# last_name       0
# email           0
# phone_number    0
# created_at      0
# dtype: int64

# %%
# Checking unique value in email
customers['email'].nunique()
# Out:
# 100

# %%
# Converting created_at column to Datetime
customers['created_at'] = pd.to_datetime(customers['created_at'])

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   customer_id   100 non-null    int64
#  1   first_name    100 non-null    object
#  2   last_name     100 non-null    object
#  3   email         100 non-null    object
#  4   phone_number  100 non-null    object
#  5   created_at    100 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
# Handling phone number column
customers['phone_number'] = customers['phone_number'].str.replace(".", "-")
customers['phone_number'] = customers['phone_number'].str.replace("x", "-")

# %%
customers['phone_number']
# Out:
# 0           374-831-2327-000
# 1      001-698-370-1197-3825
# 2               946-520-9112
# 3         915-139-9155-10333
# 4        (307)514-8871-86410
#                ...
# 95          149-832-9366-605
# 96        143-924-3829-64356
# 97    001-660-204-0662-57909
# 98         (675)384-0611-255
# 99        916-323-1800-44661
# Name: phone_number, Length: 100, dtype: object

# %% [markdown]
# # Reading and cleaning Orders table

# %%
orders.head()
# Out:
#    order_id  customer_id        order_date  total_amount     status  \
# 0         1           82  17-01-2024 19:11        163.94  Delivered
# 1         2           10  11-05-2022 02:09        334.71    Shipped
# 2         3           74  20-05-2020 20:11        674.77  Cancelled
# 3         4           22  01-08-2024 06:28        995.61  Delivered
# 4         5           19  01-09-2022 10:24        747.65    Shipped
#
#    product_id
# 0          95
# 1          96
# 2          62
# 3          74
# 4          95

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      200 non-null    int64
#  1   customer_id   200 non-null    int64
#  2   order_date    200 non-null    object
#  3   total_amount  200 non-null    float64
#  4   status        200 non-null    object
#  5   product_id    200 non-null    int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.5+ KB

# %%
orders.isna().sum()
# Out:
# order_id        0
# customer_id     0
# order_date      0
# total_amount    0
# status          0
# product_id      0
# dtype: int64

# %%
# Converting order_date column to Datetime
orders['order_date'] = pd.to_datetime(orders['order_date'])

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      200 non-null    int64
#  1   customer_id   200 non-null    int64
#  2   order_date    200 non-null    datetime64[ns]
#  3   total_amount  200 non-null    float64
#  4   status        200 non-null    object
#  5   product_id    200 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 9.5+ KB

# %% [markdown]
# # Reading and cleaning products table

# %%
products.head()
# Out:
#    product_id     product_name     category   price  stock_quantity  \
# 0           1       Money Wear         Toys  234.12             238
# 1           2      Remain Item       Sports  115.50             240
# 2           3      True Gadget  Electronics  107.63              90
# 3           4  Southern Gadget     Clothing  108.82             239
# 4           5    Resource Wear     Clothing  103.66             423
#
#             created_at
# 0  2023-08-23 13:17:46
# 1  2024-06-17 08:50:24
# 2  2025-01-15 02:58:29
# 3  2022-05-27 14:34:01
# 4  2021-03-05 14:09:38

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      100 non-null    int64
#  1   product_name    100 non-null    object
#  2   category        100 non-null    object
#  3   price           100 non-null    float64
#  4   stock_quantity  100 non-null    int64
#  5   created_at      100 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 4.8+ KB

# %%
products.isna().sum()
# Out:
# product_id        0
# product_name      0
# category          0
# price             0
# stock_quantity    0
# created_at        0
# dtype: int64

# %%
# Converting created_at column to DateTime
products['created_at'] = pd.to_datetime(products['created_at'])

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      100 non-null    int64
#  1   product_name    100 non-null    object
#  2   category        100 non-null    object
#  3   price           100 non-null    float64
#  4   stock_quantity  100 non-null    int64
#  5   created_at      100 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 4.8+ KB

# %% [markdown]
# # Reading and cleaning payments table

# %%
payments.head()
# Out:
#    payment_id  order_id    payment_method payment_status         payment_date  \
# 0           1       197            PayPal      Completed  2021-08-07 05:44:03
# 1           2       173     Bank Transfer      Completed  2022-03-01 11:16:15
# 2           3       107        Debit Card      Completed  2024-02-26 18:44:29
# 3           4       185       Credit Card        Pending  2022-01-25 22:34:56
# 4           5       141  Cash On Delivery         Failed  2024-01-02 15:03:18
#
#    amount_paid
# 0       627.38
# 1        46.76
# 2       586.88
# 3       293.61
# 4       377.65

# %%
payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   payment_id      200 non-null    int64
#  1   order_id        200 non-null    int64
#  2   payment_method  200 non-null    object
#  3   payment_status  200 non-null    object
#  4   payment_date    200 non-null    object
#  5   amount_paid     200 non-null    float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 9.5+ KB

# %%
payments.isna().sum()
# Out:
# payment_id        0
# order_id          0
# payment_method    0
# payment_status    0
# payment_date      0
# amount_paid       0
# dtype: int64

# %%
# Converting payment_date column to date time
payments['payment_date'] = pd.to_datetime(payments['payment_date'])

# %%
payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   payment_id      200 non-null    int64
#  1   order_id        200 non-null    int64
#  2   payment_method  200 non-null    object
#  3   payment_status  200 non-null    object
#  4   payment_date    200 non-null    datetime64[ns]
#  5   amount_paid     200 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 9.5+ KB

# %% [markdown]
# # Creating connection with mysql workbench and push data to mysql workbench

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings("ignore")
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqldb://root:123456789@127.0.0.1:3306/ecommerce_db')

# %%
conn = engine.connect()

# %%
customers.to_sql('customers', engine, index=False, if_exists="replace")
orders.to_sql('orders', engine, index=False, if_exists="replace")
products.to_sql('products', engine, index=False, if_exists="replace")
payments.to_sql('payments', engine, index=False, if_exists="replace")
# Out:
# 200

# %% [markdown]
# # Data validation Query

# %% [markdown]
# -- Write an SQL query to check if all Orders have a valid customer_id present in the Customers table.

# %%
q1 = 'SELECT customer_id FROM orders WHERE customer_id NOT IN (SELECT customer_id FROM customers)'

# %%
df1 = pd.read_sql(q1,conn)
df1
# Out:
# Empty DataFrame
# Columns: [customer_id]
# Index: []

# %% [markdown]
# -- Write an SQL query to find unpaid orders (i.e., orders where no successful payment exists).

# %%
q2 = 'SELECT * , p.payment_status FROM orders AS o JOIN payments AS p ON o.order_id = p.order_id WHERE p.payment_status != "Completed"'

# %%
df2 = pd.read_sql(q2,conn)
df2
# Out:
#      order_id  customer_id          order_date  total_amount     status  \
# 0         185           58 2020-09-17 08:28:00         31.87  Cancelled
# 1         141           75 2023-10-30 19:54:00        236.26    Pending
# 2          70           27 2024-07-09 08:22:00        877.00    Shipped
# 3          65           22 2020-04-14 04:36:00        755.98  Cancelled
# 4          88           48 2025-01-17 22:31:00         21.38    Shipped
# ..        ...          ...                 ...           ...        ...
# 145       114           66 2024-10-17 15:34:00        993.50    Pending
# 146        31           23 2024-06-03 23:01:00         80.87  Cancelled
# 147        79           26 2020-04-30 23:30:00        888.58    Pending
# 148        77           10 2024-02-13 11:59:00        549.57    Shipped
# 149         6           68 2024-08-30 22:33:00        183.19    Pending
#
#      product_id  payment_id  order_id    payment_method payment_status  \
# ...

# %% [markdown]
# -- How can you verify that each Payment record correctly references an existing order_id?

# %%
q3 = 'SELECT order_id  FROM payments  WHERE payment_id NOT IN (SELECT order_id FROM orders)'

# %%
df3 = pd.read_sql(q3,conn)
df3
# Out:
# Empty DataFrame
# Columns: [order_id]
# Index: []

# %% [markdown]
# # Basic Queries

# %% [markdown]
# -- Retrieve all customer details.

# %%
q4 = 'SELECT * FROM customers'

# %%
df4 = pd.read_sql(q4,conn)
df4
# Out:
#     customer_id first_name last_name                      email  \
# 0             1     Regina     Banks           kjones@petty.biz
# 1             2       Mark      Pena      mercedes42@warner.com
# 2             3     Amanda    Carney   ricardosimmons@gmail.com
# 3             4    Brandon       Lee  kelleycharles@hotmail.com
# 4             5    Theresa   Ramirez        amybrown@butler.biz
# ..          ...        ...       ...                        ...
# 95           96   Brittany     Lopez        ysanchez@duncan.com
# 96           97   Benjamin  Cantrell        crystal86@wells.com
# 97           98     Bailey     Jones   carrollcharles@yahoo.com
# 98           99       Adam   Perkins            uluna@smith.net
# 99          100    Patrick      Bond         daniel94@smith.net
#
#               phone_number          created_at
# 0         374-831-2327-000 2022-11-20 19:15:32
# 1    001-698-370-1197-3825 2025-02-08 03:18:03
# 2             946-520-9112 2022-06-28 09:04:15
# ...

# %% [markdown]
# -- List all orders with their total amount and status.

# %%
q5 = 'SELECT * FROM orders;'

# %%
df5 = pd.read_sql(q5,conn)
df5
# Out:
#      order_id  customer_id          order_date  total_amount     status  \
# 0           1           82 2024-01-17 19:11:00        163.94  Delivered
# 1           2           10 2022-05-11 02:09:00        334.71    Shipped
# 2           3           74 2020-05-20 20:11:00        674.77  Cancelled
# 3           4           22 2024-08-01 06:28:00        995.61  Delivered
# 4           5           19 2022-09-01 10:24:00        747.65    Shipped
# ..        ...          ...                 ...           ...        ...
# 195       196           28 2024-02-17 10:04:00        773.95    Shipped
# 196       197           98 2022-08-07 21:36:00        871.39  Cancelled
# 197       198           36 2024-11-26 20:42:00        712.46    Shipped
# 198       199           86 2020-05-13 20:20:00        104.72  Delivered
# 199       200           29 2023-07-12 21:42:00         52.29    Pending
#
#      product_id
# 0            95
# 1            96
# 2            62
# 3            74
# ...

# %% [markdown]
# -- Find all products that belong to the ‘Electronics’ category.

# %%
q6 = 'SELECT product_name FROM products WHERE category = "Electronics";'

# %%
df6 = pd.read_sql(q6,conn)
df6
# Out:
#         product_name
# 0        True Gadget
# 1      Shoulder Tool
# 2      Out Accessory
# 3         Break Wear
# 4          Cell Tool
# 5      Myself Device
# 6            Pm Tool
# 7          Away Wear
# 8        Much Gadget
# 9           Job Wear
# 10      Several Tool
# 11  Person Accessory
# 12         Girl Tool
# 13    Address Device

# %% [markdown]
# # Intermediate Queries

# %% [markdown]
# -- Find the total number of orders placed by each customer (customer_id and count).

# %%
q7 = '''SELECT c.customer_id, COUNT(o.customer_id) FROM customers as c
JOIN orders as o ON c.customer_id = o.customer_id
GROUP BY c.customer_id;'''

# %%
df7 = pd.read_sql(q7,conn)
df7
# Out:
#     customer_id  COUNT(o.customer_id)
# 0             2                     3
# 1             3                     4
# 2             4                     2
# 3             5                     2
# 4             8                     2
# ..          ...                   ...
# 78           94                     2
# 79           95                     2
# 80           96                     3
# 81           97                     5
# 82           98                     3
#
# [83 rows x 2 columns]

# %% [markdown]
# -- Retrieve a list of all orders, including customer names and order status.

# %%
q8 = """SELECT o.order_id, o.customer_id, c.first_name, c.last_name , o.status
FROM customers as c
JOIN orders as o ON c.customer_id = o.customer_id;"""

# %%
df8 = pd.read_sql(q8,conn)
df8
# Out:
#      order_id  customer_id first_name last_name     status
# 0           1           82     Thomas    Steele  Delivered
# 1           2           10      Carla     Young    Shipped
# 2           3           74      Shawn     Brown  Cancelled
# 3           4           22      Tammy      Byrd  Delivered
# 4           5           19     Robert   Gardner    Shipped
# ..        ...          ...        ...       ...        ...
# 195       196           28      Sarah      Mack    Shipped
# 196       197           98     Bailey     Jones  Cancelled
# 197       198           36       John      Webb    Shipped
# 198       199           86     Glenda   Sampson  Delivered
# 199       200           29      Keith     Huang    Pending
#
# [200 rows x 5 columns]

# %% [markdown]
# -- Find the total revenue (sum of all orders) generated.

# %%
q9 = """SELECT SUM(total_amount) as total_revenue 
FROM orders;"""

# %%
df9 = pd.read_sql(q9,conn)
df9
# Out:
#    total_revenue
# 0       99055.83

# %% [markdown]
# -- Identify customers who have placed more than 3 orders.

# %%
q10 = """SELECT c.customer_id, c.first_name, c.last_name, COUNT(o.customer_id) as total_orders
FROM customers as c
JOIN orders as o ON c.customer_id = o.customer_id
GROUP BY c.customer_id,c.first_name, c.last_name
HAVING total_orders > 3;"""

# %%
df10 = pd.read_sql(q10,conn)
df10
# Out:
#     customer_id first_name last_name  total_orders
# 0             3     Amanda    Carney             4
# 1            10      Carla     Young             4
# 2            12     Marcia   Hoffman             5
# 3            13     Sandra  Martinez             4
# 4            22      Tammy      Byrd             5
# 5            32       Greg     Moran             5
# 6            48  Stephanie    Chavez             4
# 7            49   Veronica  Williams             5
# 8            54     Latoya     Lopez             4
# 9            60     Andrew    Walker             4
# 10           79     Joseph     Myers             5
# 11           89    Melissa    Murray             4
# 12           97   Benjamin  Cantrell             5

# %% [markdown]
# -- Retrieve all completed payments and include the associated order details.

# %%
q11 = """SELECT *, o.order_date,o.total_amount
FROM payments AS p
JOIN orders AS o ON p.order_id = o.order_id
WHERE p.payment_status = "Completed";"""

# %%
df11 = pd.read_sql(q11,conn)
df11
# Out:
#     payment_id  order_id    payment_method payment_status        payment_date  \
# 0            1       197            PayPal      Completed 2021-08-07 05:44:03
# 1            2       173     Bank Transfer      Completed 2022-03-01 11:16:15
# 2            3       107        Debit Card      Completed 2024-02-26 18:44:29
# 3           10        43            PayPal      Completed 2022-04-16 13:46:52
# 4           14       126            PayPal      Completed 2020-01-02 15:18:01
# 5           16       181       Credit Card      Completed 2022-10-24 20:48:54
# 6           21       183  Cash On Delivery      Completed 2024-12-03 10:51:45
# 7           30        12     Bank Transfer      Completed 2021-08-08 12:12:45
# 8           32        95  Cash On Delivery      Completed 2020-04-07 06:10:44
# 9           41        22     Bank Transfer      Completed 2022-09-06 02:30:17
# 10          47       119        Debit Card      Completed 2023-01-03 03:36:33
# ...

# %% [markdown]
#  # Advanced Queries

# %% [markdown]
# -- Find the top 5 customers who have spent the most on orders.

# %%
q12 = """SELECT c.customer_id, c.first_name, c.last_name, c.email, SUM(o.total_amount) total_spent
FROM customers AS c
JOIN orders AS o ON c.customer_id = o.customer_id
GROUP BY c.customer_id,c.first_name, c.last_name, c.email
ORDER BY total_spent DESC
LIMIT 5;"""

# %%
df12 = pd.read_sql(q12,conn)
df12
# Out:
#    customer_id first_name last_name                          email  \
# 0           12     Marcia   Hoffman             xmurillo@yahoo.com
# 1           22      Tammy      Byrd  williamsonsabrina@hotmail.com
# 2           97   Benjamin  Cantrell            crystal86@wells.com
# 3           10      Carla     Young                csoto@yahoo.com
# 4           49   Veronica  Williams            cobrien@hotmail.com
#
#    total_spent
# 0      3335.72
# 1      3323.19
# 2      3153.06
# 3      2557.67
# 4      2554.51

# %% [markdown]
# -- List all orders where the payment was either ‘Pending’ or ‘Failed’.

# %%
q13 = """SELECT o.order_id , p.payment_id, p.payment_status
FROM orders AS o
JOIN payments AS p ON p.order_id = o.order_id
WHERE p.payment_status = "Pending" OR p.payment_status = "Failed";"""

# %%
df13 = pd.read_sql(q13,conn)
df13
# Out:
#     order_id  payment_id payment_status
# 0        185           4        Pending
# 1        141           5         Failed
# 2         70           6         Failed
# 3         65           7         Failed
# 4         68          11        Pending
# ..       ...         ...            ...
# 92        93         185         Failed
# 93       170         188        Pending
# 94        31         196        Pending
# 95        77         198         Failed
# 96         6         200        Pending
#
# [97 rows x 3 columns]

# %% [markdown]
# -- Find the most popular product category based on the number of orders.

# %%
q14 = """SELECT p.category, COUNT(o.order_id) AS total_order_count
FROM products AS p
JOIN orders AS o ON p.product_id = o.product_id
GROUP BY p.category
ORDER BY  total_order_count DESC
LIMIT 1;"""

# %%
df14 = pd.read_sql(q14,conn)
df14
# Out:
#    category  total_order_count
# 0  Clothing                 45

# %% [markdown]
# -- Identify orders that were placed but have no successful payment recorded.

# %%
q15 = """SELECT o.order_id, o.customer_id, o.total_amount, o.status, p.payment_status
FROM orders AS o
JOIN payments AS p ON p.order_id = o.order_id
WHERE p.payment_status != "Completed";"""

# %%
df15 = pd.read_sql(q15,conn)
df15
# Out:
#      order_id  customer_id  total_amount     status payment_status
# 0         185           58         31.87  Cancelled        Pending
# 1         141           75        236.26    Pending         Failed
# 2          70           27        877.00    Shipped         Failed
# 3          65           22        755.98  Cancelled         Failed
# 4          88           48         21.38    Shipped       Refunded
# ..        ...          ...           ...        ...            ...
# 145       114           66        993.50    Pending       Refunded
# 146        31           23         80.87  Cancelled        Pending
# 147        79           26        888.58    Pending       Refunded
# 148        77           10        549.57    Shipped         Failed
# 149         6           68        183.19    Pending        Pending
#
# [150 rows x 5 columns]

# %% [markdown]
# -- Calculate the average order value (AOV) per customer.

# %%
q16 = """SELECT c.customer_id, c.first_name, c.last_name, c.email,AVG(o.total_amount) AS average_orders
FROM customers AS c
JOIN orders AS o ON c.customer_id = o.customer_id
GROUP BY c.customer_id,c.first_name, c.last_name, c.email;"""

# %%
df16 = pd.read_sql(q16,conn)
df16
# Out:
#     customer_id first_name last_name                            email  \
# 0            82     Thomas    Steele    mckinneychristopher@adams.com
# 1            10      Carla     Young                  csoto@yahoo.com
# 2            74      Shawn     Brown           sheila54@henderson.com
# 3            22      Tammy      Byrd    williamsonsabrina@hotmail.com
# 4            19     Robert   Gardner    montgomeryelizabeth@yahoo.com
# ..          ...        ...       ...                              ...
# 78           20      Bobby    Oliver           beardsylvia@kelley.com
# 79           93     Brenda   Edwards       harrisalexander@flores.com
# 80           62    Chelsea    Flores           daviskathryn@yahoo.com
# 81           59      Emily    Garcia          mark05@collins-hart.org
# 82           78     Connie      Love  lararobert@atkinson-winters.biz
#
#     average_orders
# 0       192.415000
# 1       639.417500
# 2       576.756667
# 3       664.638000
# 4       747.650000
# ...

# %% [markdown]
# # Business-Oriented Analytical Questions

# %% [markdown]
# -- Identify which payment method is most commonly used.

# %%
q17 = """SELECT payment_method, COUNT(payment_method) AS count
FROM payments
GROUP BY payment_method
ORDER BY count DESC
LIMIT 1;"""

# %%
df17 = pd.read_sql(q17,conn)
df17
# Out:
#      payment_method  count
# 0  Cash On Delivery     48

# %% [markdown]
# -- Determine the percentage of orders that were canceled.

# %%
q18 = """SELECT (SUM(CASE WHEN status = 'Cancelled' THEN 1 ELSE 0 END) * 100 / COUNT(*)) AS percentage
FROM orders;"""

# %%
df18 = pd.read_sql(q18,conn)
df18
# Out:
#    percentage
# 0        22.0

# %% [markdown]
# -- Find out the month in which the most orders were placed.

# %%
q19 = """SELECT MONTH(order_date) AS month, COUNT(*)
FROM orders 
GROUP BY MONTH(order_date)
LIMIT 1;"""

# %%
df19 = pd.read_sql(q19,conn)
df19
# Out:
#    month  COUNT(*)
# 0      1        22

# %% [markdown]
# # Closing SQL connection

# %%
conn.close()
